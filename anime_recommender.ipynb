# %% [markdown]
# # Simple Recommender

# %%
# Import Pandas
import pandas as pd

# Load Movies Metadata
metadata = pd.read_csv('Anime_data.csv', low_memory=False)

# Print the first three rows
metadata.head()
# Out:
#    Anime_id                            Title  \
# 0         1                     Cowboy Bebop
# 1         5  Cowboy Bebop: Tengoku no Tobira
# 2         6                           Trigun
# 3         7               Witch Hunter Robin
# 4         8                   Bouken Ou Beet
#
#                                                Genre  \
# 0  ['Action', 'Adventure', 'Comedy', 'Drama', 'Sc...
# 1  ['Action', 'Space', 'Drama', 'Mystery', 'Sci-Fi']
# 2  ['Action', 'Sci-Fi', 'Adventure', 'Comedy', 'D...
# 3  ['Action', 'Magic', 'Police', 'Supernatural', ...
# 4  ['Adventure', 'Fantasy', 'Shounen', 'Supernatu...
#
#                                             Synopsis   Type  \
# 0  In the year 2071, humanity has colonized sever...     TV
# 1  Another day, another bounty—such is the life o...  Movie
# 2  Vash the Stampede is the man with a $$60,000,0...     TV
# 3  Witches are individuals with special powers li...     TV
# 4  It is the dark century and the people are suff...     TV
#
#                        Producer              Studio  Rating  ScoredBy  \
# 0             ['Bandai Visual']         ['Sunrise']    8.81  363889.0
# 1  ['Sunrise', 'Bandai Visual']           ['Bones']    8.41  111187.0
# 2      ['Victor Entertainment']        ['Madhouse']    8.31  197451.0
# 3             ['Bandai Visual']         ['Sunrise']    7.34   31875.0
# 4                           NaN  ['Toei Animation']    7.04    4757.0
#
#    Popularity   Members  Episodes    Source                         Aired  \
# 0        39.0  704490.0      26.0  Original   Apr 3, 1998 to Apr 24, 1999
# 1       475.0  179899.0       1.0  Original                   Sep 1, 2001
# 2       158.0  372709.0      26.0     Manga   Apr 1, 1998 to Sep 30, 1998
# 3      1278.0   74889.0      26.0  Original   Jul 2, 2002 to Dec 24, 2002
# 4      3968.0   11247.0      52.0     Manga  Sep 30, 2004 to Sep 29, 2005
#
#                                                 Link
# 0       https://myanimelist.net/anime/1/Cowboy_Bebop
# 1  https://myanimelist.net/anime/5/Cowboy_Bebop__...
# 2             https://myanimelist.net/anime/6/Trigun
# 3  https://myanimelist.net/anime/7/Witch_Hunter_R...
# 4     https://myanimelist.net/anime/8/Bouken_Ou_Beet

# %%
# Calculate mean of vote average column
C = metadata['Rating'].mean()
print(C)
# Out:
# 6.287866897746967

# %%
# Calculate the minimum number of votes required to be in the chart, m
m = metadata['ScoredBy'].quantile(0.90)
print(m)
# Out:
# 24156.599999999995

# %%
# Filter out all qualified movies into a new DataFrame
q_movies = metadata.copy().loc[metadata['ScoredBy'] >= m]
q_movies.shape
# Out:
# (1323, 15)

# %%
metadata.shape
# Out:
# (17002, 15)

# %%
# Function that computes the weighted rating of each movie
def weighted_rating(x, m=m, C=C):
    v = x['ScoredBy']
    R = x['Rating']
    # Calculation based on the IMDB formula
    return (v/(v+m) * R) + (m/(m+v) * C)

# %%
# Define a new feature 'score' and calculate its value with `weighted_rating()`
q_movies['Score'] = q_movies.apply(weighted_rating, axis=1)

# %%
#Sort movies based on score calculated above
q_movies = q_movies.sort_values('Score', ascending=False)

#Print the top 15 movies
q_movies[['Title', 'ScoredBy', 'Rating', 'Score']].head(20)
# Out:
#                                                    Title   ScoredBy  Rating  \
# 3634                    Fullmetal Alchemist: Brotherhood   730784.0    9.25
# 10110                                     Kimi no Na wa.   467437.0    9.19
# 5031                                         Steins;Gate   561405.0    9.14
# 5725                              Hunter x Hunter (2011)   400879.0    9.11
# 3263                                Clannad: After Story   362434.0    9.01
# 2461                  Code Geass: Hangyaku no Lelouch R2   541989.0    8.95
# 8695                                      Koe no Katachi   293169.0    9.04
# 183                        Sen to Chihiro no Kamikakushi   496902.0    8.92
# 7747                             Shigatsu wa Kimi no Uso   411504.0    8.88
# 1292                     Code Geass: Hangyaku no Lelouch   625466.0    8.79
# 0                                           Cowboy Bebop   363889.0    8.81
# 9249                                       One Punch Man   687965.0    8.73
# 10432  Haikyuu!!: Karasuno Koukou vs. Shiratorizawa G...   157302.0    8.99
# 149                                        Mononoke Hime   332946.0    8.80
# 1665                          Tengen Toppa Gurren Lagann   448287.0    8.74
# 1257                                          Death Note  1006242.0    8.67
# 726                                              Gintama   141307.0    9.01
# 10727                   Boku no Hero Academia 2nd Season   345545.0    8.76
# 8703                             Haikyuu!! Second Season   204532.0    8.87
# 11335                                      Made in Abyss   164813.0    8.91
#
#           Score
# 3634   9.155218
# 10110  9.047391
# 5031   9.022339
# 5725   8.949606
# 3263   8.839904
# 2461   8.836411
# 8695   8.830492
# 183    8.797973
# 7747   8.736271
# 1292   8.696957
# 0      8.652992
# 9249   8.647158
# 10432  8.630280
# 149    8.630064
# 1665   8.614620
# 1257   8.614153
# 726    8.612586
# 10727  8.598469
# 8703   8.597247
# 11335  8.574804
